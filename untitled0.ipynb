# %% [markdown]
# <a href="https://colab.research.google.com/github/maneakansha36/my_first_repository/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score,recall_score,f1_score
import seaborn as sns
from scipy.stats.mstats import winsorize

# %%
df = pd.read_csv("/content/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(240)

# %%
num_cols = df.select_dtypes(np.number)
num_cols
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
for i in num_cols:

  plt.figure(figsize=(5,5))
  plt.title(i)
  plt.boxplot(df[i])

# %%
alcohol_enco = LabelEncoder()
df['alcohol'] = alcohol_enco.fit_transform(df['alcohol'])

# %%
for i in df.columns:
  plt.figure(figsize=(5,5))
  plt.title(i)
  plt.hist(df[i])

# %%
density_value = StandardScaler()

df['density'] = density_value.fit_transform(df[['density']])

# %%
sal = MinMaxScaler()
df['density'] = sal.fit_transform(df[['density']])

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.055533         -0.199852     0.108053
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
y = df['quality']
x = df.drop(['density','quality'], axis =1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2,random_state =42)

# %%
y_train.value_counts()
# Out:
# quality
# 5    551
# 6    506
# 7    157
# 4     43
# 8     13
# 3      9
# Name: count, dtype: int64

# %%
x_train.shape
# Out:
# (1279, 10)

# %%
y = df['quality']
x = df.drop(['density','quality'], axis =1)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2,random_state =42)

from sklearn.linear_model import LogisticRegression

# Create the logistic regression model
log_model = LogisticRegression()

# Train the model on the training data
log_model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = log_model.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("Accuracy score is",accuracy_score(y_test,y_pred))
print("Presicion score is",precision_score(y_test,y_pred, average='weighted'))
print("Recall score is",recall_score(y_test,y_pred, average='weighted'))
print("f1 score is",f1_score(y_test,y_pred, average='weighted'))
# Out:
# Accuracy score is 0.55625
# Presicion score is 0.5112686200809267
# Recall score is 0.55625
# f1 score is 0.5276945016911047
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 0,  0,  1,  0,  0,  0],
#        [ 0,  0,  6,  4,  0,  0],
#        [ 0,  0, 98, 27,  5,  0],
#        [ 0,  0, 51, 72,  9,  0],
#        [ 0,  0,  4, 30,  8,  0],
#        [ 0,  0,  0,  4,  1,  0]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
metric_k = []
neighbours = np.arange(3,15)
for k in neighbours:
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(x_train, y_train)
  y_pred = knn.predict(x_test)
  accuracy = accuracy_score(y_test, y_pred)
  metric_k.append(accuracy)

# %%
plt.plot(neighbours,metric_k,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors =6,metric ='minkowski',p=2)
classifier.fit(x_train,y_train)
y_pred1 = classifier.predict(x_test)
acc = accuracy_score(y_test,y_pred1)
metric_k.append(acc)

# %%
print("Accuracy score is",accuracy_score(y_test,y_pred1))
print("Presicion score is",precision_score(y_test,y_pred1, average='weighted'))
print("Recall score is",recall_score(y_test,y_pred1, average='weighted'))
print("f1 score is",f1_score(y_test,y_pred1, average='weighted'))
confusion_matrix(y_test, y_pred1)
# Out:
# Accuracy score is 0.55
# Presicion score is 0.5176320121951219
# Recall score is 0.55
# f1 score is 0.5281475489028297
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([[ 0,  1,  0,  0,  0,  0],
#        [ 0,  0,  7,  3,  0,  0],
#        [ 0,  1, 97, 30,  2,  0],
#        [ 0,  1, 53, 67, 11,  0],
#        [ 0,  0,  6, 24, 12,  0],
#        [ 0,  0,  1,  1,  3,  0]])

# %%
classifier = KNeighborsClassifier(n_neighbors = 10,metric ='minkowski',p=2)
classifier.fit(x_train,y_train)
y_pred3 = classifier.predict(x_test)
print("Accuracy score is",accuracy_score(y_test,y_pred3))
print("Presicion score is",precision_score(y_test,y_pred3, average='weighted'))
print("Recall score is",recall_score(y_test,y_pred3, average='weighted'))
print("f1 score is",f1_score(y_test,y_pred3, average='weighted'))
confusion_matrix(y_test, y_pred3)
# Out:
# Accuracy score is 0.55625
# Presicion score is 0.5255688048245614
# Recall score is 0.55625
# f1 score is 0.533096640672275
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([[ 0,  1,  0,  0,  0,  0],
#        [ 0,  1,  8,  1,  0,  0],
#        [ 0,  1, 98, 29,  2,  0],
#        [ 0,  0, 50, 70, 12,  0],
#        [ 0,  0,  4, 29,  9,  0],
#        [ 0,  0,  0,  4,  1,  0]])

# %%
metric_k1 = []
neighbours1 = np.arange(3,15)
for k in neighbours1:
  classifier = KNeighborsClassifier(n_neighbors = k, metric ='minkowski',p=3)
  classifier.fit(x_train,y_train)
  y_pre = classifier.predict(x_test)
  acc1 = accuracy_score(y_test,y_pre)
  metric_k1.append(acc1)
plt.plot(neighbours1,metric_k1,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier1 = KNeighborsClassifier(n_neighbors = 8,metric ='minkowski',p=3)
classifier1.fit(x_train,y_train)
y_pre1 = classifier.predict(x_test)
print("Accuracy score is",accuracy_score(y_test,y_pre1))
print("Presicion score is",precision_score(y_test,y_pre1, average='weighted'))
print("Recall score is",recall_score(y_test,y_pre1, average='weighted'))
print("f1 score is",f1_score(y_test,y_pre1, average='weighted'))
confusion_matrix(y_test, y_pre1)
# Out:
# Accuracy score is 0.540625
# Presicion score is 0.49728260869565216
# Recall score is 0.540625
# f1 score is 0.5141145599880472
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([[ 0,  0,  0,  1,  0,  0],
#        [ 0,  0,  6,  3,  1,  0],
#        [ 0,  0, 98, 29,  3,  0],
#        [ 0,  0, 53, 66, 13,  0],
#        [ 0,  0,  4, 29,  9,  0],
#        [ 0,  0,  0,  4,  1,  0]])
